# %% [markdown]
# ## AUTHOR : VAISHNAV KRISHNA P
# ### PROJECT NAME: GYM DATA ANALYSIS(DATA SCIENCE)
# #### DATA COLLECTION SOURCE: https://www.kaggle.com/datasets/valakhorasani/gym-members-exercise-dataset
# ##### TASKS :
# * This dataset provides a detailed overview of gym members' exercise routines, physical attributes, and fitness metrics. It contains 973 samples of gym data, including key performance indicators such as heart rate, calories burned, and workout duration. Each entry also includes demographic data and experience levels, allowing for comprehensive analysis of fitness patterns, athlete progression, and health trends.
# ###### FEATURES:
# * Age: Age of the gym member.
# * Gender: Gender of the gym member (Male or Female).
# * Weight (kg): Member’s weight in kilograms.
# * Height (m): Member’s height in meters.
# * Max_BPM: Maximum heart rate (beats per minute) during workout sessions.
# * Avg_BPM: Average heart rate during workout sessions.
# * Resting_BPM: Heart rate at rest before workout.
# * Session_Duration (hours): Duration of each workout session in hours.
# * Calories_Burned: Total calories burned during each session.
# * Workout_Type: Type of workout performed (e.g., Cardio, Strength, Yoga, HIIT).
# * Fat_Percentage: Body fat percentage of the member.
# * Water_Intake (liters): Daily water intake during workouts.
# * Workout_Frequency (days/week): Number of workout sessions per week.
# * Experience_Level: Level of experience, from beginner (1) to expert (3).
# * BMI: Body Mass Index, calculated from height and weight.

# %%
# importing the dependencies 
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Loading the dataset 
df = pd.read_csv("gym_members_exercise_tracking.csv")

# %%
# first 5 rows 
df.head()
# Out:
#    Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0   56    Male         88.3        1.71      180      157           60
# 1   46  Female         74.9        1.53      179      151           66
# 2   32  Female         68.1        1.66      167      122           54
# 3   25    Male         53.2        1.70      190      164           56
# 4   38    Male         46.1        1.79      188      158           68
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                      1.69           1313.0         Yoga            12.6
# 1                      1.30            883.0         HIIT            33.9
# 2                      1.11            677.0       Cardio            33.4
# 3                      0.59            532.0     Strength            28.8
# 4                      0.64            556.0     Strength            29.2
#
#    Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# ...

# %%
# shape of the dataframe 
df.shape
# Out:
# (973, 15)

# %%
# Statistical description of the dataset 
df.describe()
# Out:
#               Age  Weight (kg)  Height (m)     Max_BPM     Avg_BPM  \
# count  973.000000   973.000000   973.00000  973.000000  973.000000
# mean    38.683453    73.854676     1.72258  179.883864  143.766701
# std     12.180928    21.207500     0.12772   11.525686   14.345101
# min     18.000000    40.000000     1.50000  160.000000  120.000000
# 25%     28.000000    58.100000     1.62000  170.000000  131.000000
# 50%     40.000000    70.000000     1.71000  180.000000  143.000000
# 75%     49.000000    86.000000     1.80000  190.000000  156.000000
# max     59.000000   129.900000     2.00000  199.000000  169.000000
#
#        Resting_BPM  Session_Duration (hours)  Calories_Burned  Fat_Percentage  \
# count   973.000000                973.000000       973.000000      973.000000
# mean     62.223022                  1.256423       905.422405       24.976773
# std       7.327060                  0.343033       272.641516        6.259419
# ...

# %%
# Duplicate recordes
df.duplicated().sum()
# Out:
# 0

# %%
df['Age'].min()
# Out:
# 18

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Weight (kg)', 'Height (m)', 'Max_BPM', 'Avg_BPM',
#        'Resting_BPM', 'Session_Duration (hours)', 'Calories_Burned',
#        'Workout_Type', 'Fat_Percentage', 'Water_Intake (liters)',
#        'Workout_Frequency (days/week)', 'Experience_Level', 'BMI'],
#       dtype='object')

# %%
# Lets first check the distribution of age 
plt.title("HISTOGRAM: AGE FEATURE")
sns.histplot(data=df['Age'], kde=True, bins=20)
plt.show()

# %% [markdown]
# * From the analysis, we understood that most of the GYM customers are in the age range of (40-60) as compare to (20-40).

# %%
# Lets understand the difference of fat in the body with the Years of exoerience.
plt.title("BAR PLOT: EXPERIENCE LEVEL VS FAT PERCENTAGE")
sns.barplot(data=df, x='Experience_Level', y='Fat_Percentage', estimator='median', hue='Gender',width=0.5,gap=0.1)
plt.show()

# %% [markdown]
# * From the above figure, it is clear that people who have more experiences in GYM has reduced their fat percentage in the body.

# %%
# Loop over each feature for visualization
sns.set_theme(style="whitegrid", palette="pastel")
for feature in ['Gender', 'Workout_Type', 'Experience_Level', 'Workout_Frequency (days/week)']:
    fig, axes = plt.subplots(1, 2, figsize=(12, 5))
    
    # Bar plot for the feature
    sns.countplot(data=df, x=feature, ax=axes[0])
    axes[0].set_title(f'Distribution of {feature}')
    axes[0].set_ylabel('Count')
    axes[0].set_xlabel(feature)
    
    # Pie plot for the feature
    df[feature].value_counts().plot.pie(autopct='%1.1f%%', ax=axes[1], startangle=90)
    axes[1].set_ylabel('')  
    axes[1].set_title(f'{feature} Proportion')
    
    # Show plots side by side
    plt.suptitle(f"DISTRIBUTION OF {feature} CATEGORICAL FEATURE")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### FINDING FROM THE ANALYSIS:
# * Gender Distribution: Male members dominate, indicating a stronger preference for gym workouts compared to females.
# * Exercise Preference: Strength and cardio are popular among members, suggesting these as highly favored workout types.
# * Experience Level: Members with 1-2 years of experience are the majority, while those with 3+ years are fewer, possibly indicating declining long-term interest.
# * Workout Frequency: Most members prefer 3-4 sessions per week, which may be an optimal strategy for consistent gym engagement.

# %%
# scatter plot : Calories burn and Average BPM and Session_Duration (hours)
sns.set_theme(style="whitegrid", palette="pastel")
fig, axes = plt.subplots(1,2,figsize=(8,5))

# Scatter  plot for calroes burned  with BPM
axes[0].set_title("Calories burn and AVG BPM")
sns.scatterplot(data=df, x='Calories_Burned', y='Avg_BPM',hue="Gender",markers=True, ax=axes[0])

# scatter plot for calories burned wirh session duration
axes[1].set_title("Calories burn and AVG BPM")
sns.scatterplot(data=df, x='Calories_Burned', y='Session_Duration (hours)',hue="Gender", ax=axes[1])

plt.tight_layout()
plt.show()

# %%
# Group by analysis 
df.groupby("Workout_Type")['Calories_Burned'].mean() # HIIT(High intensity interval training) has requires to burn high amount of calories.
# Out:
# Workout_Type
# Cardio      884.513725
# HIIT        925.805430
# Strength    910.697674
# Yoga        903.188285
# Name: Calories_Burned, dtype: float64

# %%
df.nunique()
# Out:
# Age                               42
# Gender                             2
# Weight (kg)                      532
# Height (m)                        51
# Max_BPM                           40
# Avg_BPM                           50
# Resting_BPM                       25
# Session_Duration (hours)         147
# Calories_Burned                  621
# Workout_Type                       4
# Fat_Percentage                   239
# Water_Intake (liters)             23
# Workout_Frequency (days/week)      4
# Experience_Level                   3
# BMI                              771
# dtype: int64

# %%
# Histogram: BMI, 
sns.set(style="whitegrid")
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Plot histogram for Fat_Percentage
sns.histplot(df['Fat_Percentage'], bins=20, kde=True, ax=axes[0], color='skyblue')
axes[0].set_title('Distribution of Fat Percentage')
axes[0].set_xlabel('Fat Percentage')
axes[0].set_ylabel('Frequency')

# Plot histogram for BMI
sns.histplot(df['BMI'], bins=20, kde=True, ax=axes[1], color='salmon')
axes[1].set_title('Distribution of BMI')
axes[1].set_xlabel('BMI')
axes[1].set_ylabel('Frequency')

# Show the plots
plt.tight_layout()
plt.show()

# %%
df['BMI'].skew() # positively skewed
# Out:
# 0.7636478559612702

# %%
df['Fat_Percentage'].skew() # Negatively skewed
# Out:
# -0.6352246756335007

# %% [markdown]
# * BMI Level: The distribution of BMI is positively skewed, meaning that most values are concentrated on the lower end with a tail extending toward higher BMI values. This indicates a majority of members have lower BMI levels, with fewer outliers in the higher range.
# * **Fat Percentage: The distribution of fat percentage is negatively skewed, with most values concentrated at the higher end and a tail extending toward lower fat percentages. This suggests that members generally have higher fat percentages, with fewer having exceptionally low values.
